# %%
import pandas as pd
import numpy as np

from datetime import timedelta
from datetime import datetime

# %%
# 년도별 기상 데이터 가져오기
for year in range(2021, 2024) :
  globals()['weather_'+str(year)] = f'OBS_ASOS_TIM_{year}.csv'
  globals()['w_data_'+str(year)] = pd.read_csv(globals()['weather_'+str(year)], encoding='cp949')

w_data = pd.concat((w_data_2021, w_data_2022, w_data_2023), axis=0)

w_data.head()
# Out:
#     지점 지점명                일시  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  풍속(m/s)  \
# 0  108  서울  2021-01-01 00:00    -8.3       NaN      NaN        9.0      1.8
# 1  108  서울  2021-01-01 01:00    -8.7       NaN      NaN        NaN      2.4
# 2  108  서울  2021-01-01 02:00    -9.1       NaN      NaN        NaN      1.6
# 3  108  서울  2021-01-01 03:00    -9.3       NaN      NaN        NaN      1.1
# 4  108  서울  2021-01-01 04:00    -9.3       NaN      NaN        NaN      0.3
#
#    풍속 QC플래그  풍향(16방위)  ...  최저운고(100m )  시정(10m)  지면상태(지면상태코드)  현상번호(국내식)  \
# 0       NaN     250.0  ...          NaN     2000           NaN        NaN
# 1       NaN     270.0  ...          NaN     2000           NaN        NaN
# 2       NaN     270.0  ...          NaN     2000           NaN        NaN
# 3       NaN     250.0  ...          NaN     2000           NaN        NaN
# 4       NaN       0.0  ...          NaN     2000           NaN        NaN
#
# ...

# %%
print(len(w_data))
# Out:
# 26280

# %%
day_list = pd.read_csv('2201_2312_date.csv')

print(len(day_list))
# Out:
# 1095

# %%
w_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26280 entries, 0 to 8759
# Data columns (total 38 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   지점             26280 non-null  int64
#  1   지점명            26280 non-null  object
#  2   일시             26280 non-null  object
#  3   기온(°C)         26280 non-null  float64
#  4   기온 QC플래그       0 non-null      float64
#  5   강수량(mm)        2975 non-null   float64
#  6   강수량 QC플래그      4861 non-null   float64
#  7   풍속(m/s)        26241 non-null  float64
#  8   풍속 QC플래그       22 non-null     float64
#  9   풍향(16방위)       26241 non-null  float64
#  10  풍향 QC플래그       22 non-null     float64
#  11  습도(%)          26280 non-null  int64
#  12  습도 QC플래그       0 non-null      float64
#  13  증기압(hPa)       26280 non-null  float64
#  14  이슬점온도(°C)      26280 non-null  float64
#  15  현지기압(hPa)      26280 non-null  float64
#  16  현지기압 QC플래그     0 non-null      float64
# ...

# %%
w_data = w_data.iloc[:,[2, 3, 5, 7, 11, 15, 19, 21, 23, 25, 29, 32]]

w_data.head()
# Out:
#                  일시  기온(°C)  강수량(mm)  풍속(m/s)  습도(%)  현지기압(hPa)  일조(hr)  \
# 0  2021-01-01 00:00    -8.3      NaN      1.8     66     1016.4     NaN
# 1  2021-01-01 01:00    -8.7      NaN      2.4     68     1016.4     NaN
# 2  2021-01-01 02:00    -9.1      NaN      1.6     69     1016.2     NaN
# 3  2021-01-01 03:00    -9.3      NaN      1.1     70     1016.8     NaN
# 4  2021-01-01 04:00    -9.3      NaN      0.3     71     1016.2     NaN
#
#    일사(MJ/m2)  적설(cm)  전운량(10분위)  시정(10m)  지면온도(°C)
# 0        NaN     NaN        0.0     2000      -6.8
# 1        NaN     NaN        0.0     2000      -6.9
# 2        NaN     NaN        0.0     2000      -7.1
# 3        NaN     NaN        0.0     2000      -7.3
# 4        NaN     NaN        0.0     2000      -7.5

# %%
#w_data.to_csv("total_weather.csv", encoding='cp949')
