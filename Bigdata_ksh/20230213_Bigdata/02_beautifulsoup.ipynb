# %%
from bs4 import BeautifulSoup as bs  #pip install beautifulsoup4
import requests

# %%
url = "https://movie.naver.com/movie/running/current.naver"

page = requests.get(url)
soup = bs(page.text, 'html.parser')
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="no" http-equiv="imagetoolbar"/>
# <title>현재 상영영화 : 네이버 영화</title>
# <meta content="https://ssl.pstatic.net/imgmovie/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 현재상영작" property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1">
# <meta content="현재상영작" property="me2:category2"/>
# <meta content="현재상영작 : 네이버 영화" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/running/current.naver" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static/m/movie/icons/OG_270_270.png" property="og:image"/>
# <meta content="상영 중 영화의 예매율/평점/좋아요 순 정보 제공." property="og:description"/>
# <meta content="https://ssl.pstatic.net/imgmovie/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# <meta content="네이버 영화" property="og:article:author"/>
# <meta content="https://movie.naver.com/" property="og:article:author:url"/>
# <link href="https://ssl.pstatic.net/static/m/movie/icons/naver_movie_favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/css/deploy/movie.all.css?20230120183220" rel="stylesheet" type="text/css">
# <script src="/js/deploy/movie.all.js?20230120183220" type="text/javascript"></script>
# </link></meta></meta></meta></head>
# <body>
# <div class="basic" id="wrap">
# <!-- GNB -->
# <script type="text/javascript">
# function delayed_submit(object) {
# 	if (navigator.userAgent.indexOf('MSIE') == -1) {
# 		var b = c = new Date();
#       	while ((b.getTime() - c.getTime()) < 100) {
# 			b = new Date();
#       	}
# 	}
# }
# </script>
# <script type="text/javascript">
# 	var gnb_service = "movie";
# 	var gnb_logout = "https://movie.naver.com/movie/running/current.naver";
# 	var gnb_template = "gnb_utf8";
# 	var gnb_brightness=3;
# 	var gnb_response = true;
#
# 	jindo.$Fn(function(){
# 		getGNB();
# 	}).attach(window, "load");
#
# 	jindo.$Fn(function(oEvent){ var welSource = jindo.$Element(oEvent.element);
# 			if (!welSource.isChildOf(jindo.$Element("gnb"))) {
# 				gnbAllLayerClose();
# 			}
# 	}).attach(document, 'click');
# </script>
# <!-- skip navigation -->
# <div id="u_skip">
# <a href="#header" onclick="document.getElementById('header').tabIndex=-1;document.getElementById('header').focus();return false;"><span>메인 메뉴로 바로가기</span></a>
# <a href="#content" id="gnb_goContent" onclick="document.getElementById('content').tabIndex=-1;document.getElementById('content').focus();return false;"><span>본문으로 바로가기</span></a>
# </div>
# <!-- //skip navigation -->
# <div class="gnb_container">
# <div class="gnb_content">
# <div class="gnb_box">
# <div class="gnb_wrap">
# <div id="gnb">
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn" type="text/javascript"></script>
# </div>
# </div>
# <!-- 검색창 -->
# <form action="/movie/search/result.naver" id="jSearchForm" method="get" style="margin:0;display:none;">
# <input maxlength="100" name="query" title="영화검색" type="text"/>
# <input name="section" type="hidden" value="all"/>
# <input name="ie" type="hidden" value="utf8"/>
# </form>
# <fieldset class="srch_area" id="jSearchArea">
# <legend><span class="blind">영화검색 영역</span></legend>
# <div class="srch_field_on _view">
# <span class="ipt_srch">
# <label for="ipt_tx_srch" id="search_placeholder">영화검색</label>
# <input accesskey="s" autocomplete="off" class="ipt_tx_srch" id="ipt_tx_srch" maxlength="100" name="query" style="ime-mode:active;" type="text"/>
# <span class="align"></span>
# <span class="auto_tx"><a href="#" title="자동완성 펼치기"><img alt="자동완성 펼치기" height="4" src="https://ssl.pstatic.net/static/movie/2012/06/srch_arrow_down.gif" title="자동완성 펼치기" width="7"/></a></span>
# </span>
# <button class="btn_srch" onclick="clickcr(this,'GNB.search','','',event); delayed_submit(this);" title="검색" type="submit"><span class="blind">검색</span></button>
# <!-- 자동 완성 영역임 #autocomplate_template-->
# </div>
# </fieldset>
# <!-- //검색창 -->
# </div>
# </div>
# </div>
# <!-- //GNB -->
# <!-- header -->
# <div id="header">
# <a class="blind" href="#content" title="본문으로 이동">본문 바로가기</a>
# <h1 class="svc_name">
# <a class="ci_logo" href="http://www.naver.com/" id="lnb_gonaver" title="naver로 바로가기"><img alt="NAVER" height="13" src="https://ssl.pstatic.net/static/movie/2013/07/logo_ci.png" width="62"/></a><!-- N=a:LNB.naver -->
# <a class="svc_logo" href="/" title="영화서비스홈으로 바로가기"><img alt="영화" height="19" src="https://ssl.pstatic.net/static/movie/2012/06/logo_svc.png" width="34"/></a><!-- N=a:LNB.movie -->
# </h1>
# <div class="scrollbar scrollbar-noscript" id="scrollbar">
# <div class="scrollbar-box">
# <div class="scrollbar-content">
# <div class="in_scroll">
# <ul class="navi">
# <li>
# <a class="menu01" href="/" title="영화홈"><strong>영화홈</strong></a><!-- N=a:LNB.home -->
# </li>
# <li>
# <a class="menu02_on" href="/movie/running/current.naver" title="상영작·예정작"><strong>상영작·예정작</strong></a><!-- N=a:LNB.movies -->
# <ul class="navi_sub" id="navi_movie" style="display:none">
# <li><a class="sub2_1_on" href="/movie/running/current.naver" title="현재 상영영화"><em>현재 상영영화</em></a><!-- N=a:LNB.now --></li>
# <li><a class="sub2_2" href="/movie/running/premovie.naver" title="개봉 예정영화"><em>개봉 예정영화</em></a><!-- N=a:LNB.soon --></li>
# <li><a class="sub2_4" href="/movie/running/movieclip.naver" title="예고편"><em>예고편</em></a><!-- N=a:LNB.tailer --></li>
# </ul>
# </li>
# <li>
# <a class="menu03" href="/movie/sdb/rank/rmovie.naver" title="영화랭킹"><strong>영화랭킹</strong></a><!-- N=a:LNB.db -->
# </li>
# <li>
# <a class="menu07" href="/movie/point/af/list.naver" title="평점·리뷰"><strong>평점·리뷰</strong></a><!-- N=a:LNB.comm -->
# </li>
# <li>
# <a class="menu08" href="https://serieson.naver.com/movie/home.nhn" target="_blank" title="다운로드"><strong>다운로드</strong></a><!-- N=a:LNB.download -->
# </li>
# <li class="nav_indi">
# <a href="http://tv.naver.com/indiecinema" target="_blank" title="인디극장 UP"><strong>인디극장 UP</strong></a><!-- N=a:LNB.indie -->
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="scrollbar-v">
# <div class="scrollbar-button-up"></div>
# <div class="scrollbar-track">
# <div class="scrollbar-thumb"></div>
# </div>
# <div class="scrollbar-button-down"></div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 	if ("현재 상영영화" == "상영작·예정작"
# 			|| "현재 상영영화" == "현재 상영영화"
# 			|| "현재 상영영화" == "개봉 예정영화"
# 			|| "현재 상영영화" == "TV 방영영화"
# 			|| "현재 상영영화" == "예고편") {
# 		jindo.$Element("navi_movie").show();
# 	}
# 	</script>
# <!-- //header -->
# <!-- container -->
# <div id="container">
# <!-- 프로모션 레이어 -->
# <div class="ly_promo" id="thumb_promotion_layer"><h3>원하시는 영화를 선택해보세요.</h3>
# 			화제가 되고 있는 최신영화 정보를 한 눈에 확인하실 수 있습니다.
# 			<a class="btn_clse" href="#" id="thumb_promotion_layer_close" title="닫기">닫기</a>
# </div>
# <!-- 상단 현재 상영작 썸네일 리스트 -->
# <div class="spot">
# <div class="top_list" id="_TopArea">
# </div>
# </div>
# <!-- //상단 현재 상영작 썸네일 리스트 -->
# <script id="_TopAreaThumbnailExpander_tpl" type="text/template">
#             <div class="zoom_img" style="width:77px;height:110px;left:{=nLeft}px">
#                 <a href="{=sUrl}">
#                     <span class="img_mask">
#                             <p>{=sTitle}</p>
#                     </span>
#                     <img src="{=sImgSrc}" alt="" />
#                 </a>
#             </div>
#         </script>
# <script type="text/javascript">
# 			jindo.$Fn(
# 				function (we) {
# 					if (jindo.$('thumb_promotion_layer') != null) {
# 						jindo.$Fn(
# 							function(e) {
# 								jindo.$Element("thumb_promotion_layer").hide();
# 								jindo.$Cookie().set("NM_THUMB_PROMOTION_BLOCK", "Y", 1000);	//1000 days
# 							}
# 						).attach(jindo.$("thumb_promotion_layer_close"), "click").attach(jindo.$("_TopArea"), "click");
# 					}
# 				}
# 			).attach(document, 'domready');
#         </script>
# <!-- content -->
# <div id="content">
# <div class="article">
# <div class="obj_section">
# <h3 class="tit_t1"><img alt="현재 상영영화" height="24" src="https://ssl.pstatic.net/static/movie/2012/09/tit_movie1.png" width="120"/></h3>
# <div class="view_sorting">
# <ul class="view_sorting_t1">
# <li class="on"><a class="item1" href="./current.naver?view=list&amp;tab=normal&amp;order=open" title="리스트뷰">리스트뷰</a><!-- N=a:now.lview --></li>
# <li><a class="item2" href="./current.naver?view=image&amp;tab=normal&amp;order=open" title="이미지뷰">이미지뷰</a><!-- N=a:now.iview --></li>
# </ul>
# </div>
# <div class="tab_t1">
# <ul class="tab_s1">
# <li class="on"><a class="item1" href="./current.naver?view=list&amp;tab=normal&amp;order=open">상영영화</a><!-- N=a:now.movie --></li>
# <!-- li ><a href="./current.naver?view=list&tab=singleTheater&order=open" class="item2">단관개봉</a --><!-- N=a:now.one --><!-- /li -->
# <li><a class="item3" href="./current.naver?view=list&amp;tab=festival">영화제</a><!-- N=a:now.festival --></li>
# </ul>
# <ul class="sorting_t1">
# <li class="on"><a class="item1" href="./current.naver?view=list&amp;tab=normal&amp;order=open" title="개봉순 정렬">개봉순</a><!-- N=a:now.day --></li>
# <li><a class="item3" href="./current.naver?view=list&amp;tab=normal&amp;order=point" title="평점순 정렬">평점순</a><!-- N=a:now.star --></li>
# <li><a class="item6" href="./current.naver?view=list&amp;tab=normal&amp;order=likeCount" title="좋아요순 정렬">좋아요순</a><!-- N=a:now.like --></li>
# </ul>
# </div>
# <h4 class="blind">상영영화</h4>
# <div class="lst_wrap">
# <ul class="lst_detail_t1">
# <li>
# <div class="thumb">
# <a href="/movie/bi/mi/basic.naver?code=209331"><img alt="라스트 버스" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20230106_104/1672967683358z8asz_JPEG/movie_image.jpg?type=m99_141_2"/></a><!-- N=a:nol.img,r:1,i:209331 -->
# </div>
# <dl class="lst_dsc">
# <dt class="tit">
# <span class="ico_rating_12">12세 관람가</span>
# <a href="/movie/bi/mi/basic.naver?code=209331">라스트 버스</a>
# <!-- N=a:nol.title,r:1,i:209331 -->
# </dt>
# <dd class="star">
# <dl class="info_star">
# <dt class="tit_t1">네티즌</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=209331#pointAfterTab"><span class="st_off"><span class="st_on" style="width:92.2%"></span></span><span class="num">9.22</span><span class="num2">참여 <em>23</em>명</span></a><!-- N=a:nol.urating -->
# </div>
# <span class="split">|</span>
# </dd>
# <dt class="tit_t2">기자 · 평론가</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=209331#pointExpertTab"><span class="st_off"><span class="st_on" style="width:50.0%"></span></span><span class="num">5.00</span><span class="num2">참여 <em>2</em>명</span></a><!-- N=a:nol.crating -->
# </div>
# </dd>
# </dl>
# </dd>
# <dd>
# <dl class="info_txt1">
# <dt class="tit_t1">개요</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.naver?genre=1">드라마</a><!-- N=a:nol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								83분
#
#
#
#
#
# 								<span class="split">|</span>
# 								2023.02.09 개봉
#
# 						</dd>
# <dt class="tit_t2">감독</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=34232">길리스 매키넌</a><!-- N=a:nol.director,r:1 -->
# </span>
# </dd>
# <dt class="tit_t3">출연</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=9220">티모시 스폴</a><!-- N=a:nol.actor,r:1 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=28004">필리스 로건</a><!-- N=a:nol.actor,r:2 -->
# </span>
# </dd>
# </dl>
# </dd>
# <dd class="info_t1">
# <div class="btn_area">
# <a class="btn_rsv" href="/movie/bi/mi/running.naver?code=209331">예매하기</a><!-- N=a:nol.ticket,r:1,i:209331 -->
# <span class="btn_t1">
# <a class="item1" href="/movie/bi/mi/photoView.naver?code=209331">포토보기</a><!-- N=a:nol.photo,r:1,i:209331 -->
# <a class="item2" href="/movie/bi/mi/mediaView.naver?code=209331&amp;mid=54124#tab">예고편</a><!-- N=a:nol.trailer,r:1,i:209331 -->
# </span>
# </div>
# </dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a href="/movie/bi/mi/basic.naver?code=224837"><img alt="원 웨이" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20230125_66/16746119971137AOTS_JPEG/movie_image.jpg?type=m99_141_2"/></a><!-- N=a:nol.img,r:2,i:224837 -->
# </div>
# <dl class="lst_dsc">
# <dt class="tit">
# <span class="ico_rating_15">15세 관람가</span>
# <a href="/movie/bi/mi/basic.naver?code=224837">원 웨이</a>
# <!-- N=a:nol.title,r:2,i:224837 -->
# </dt>
# <dd class="star">
# <dl class="info_star">
# <dt class="tit_t1">네티즌</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=224837#pointAfterTab"><span class="st_off"><span class="st_on" style="width:52.5%"></span></span><span class="num">5.25</span><span class="num2">참여 <em>8</em>명</span></a><!-- N=a:nol.urating -->
# </div>
# </dd>
# </dl>
# </dd>
# <dd>
# <dl class="info_txt1">
# <dt class="tit_t1">개요</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.naver?genre=19">액션</a><!-- N=a:nol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.naver?genre=7">스릴러</a><!-- N=a:nol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								97분
#
#
#
#
#
# 								<span class="split">|</span>
# 								2023.02.09 개봉
#
# 						</dd>
# <dt class="tit_t2">감독</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=456061">앤드류 베어드</a><!-- N=a:nol.director,r:1 -->
# </span>
# </dd>
# <dt class="tit_t3">출연</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=366800">머신 건 켈리</a><!-- N=a:nol.actor,r:1 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=865">케빈 베이컨</a><!-- N=a:nol.actor,r:2 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=342487">스톰 레이드</a><!-- N=a:nol.actor,r:3 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=173481">트래비스 핌멜</a><!-- N=a:nol.actor,r:4 -->
# </span>
# </dd>
# </dl>
# </dd>
# <dd class="info_t1">
# <div class="btn_area">
# <a class="btn_rsv" href="/movie/bi/mi/running.naver?code=224837">예매하기</a><!-- N=a:nol.ticket,r:2,i:224837 -->
# <a class="btn_download" href="https://serieson.naver.com/tvstore/detail.nhn?mcode=224837" target="_blank">다운로드</a>
# <span class="btn_t1">
# <a class="item1" href="/movie/bi/mi/photoView.naver?code=224837">포토보기</a><!-- N=a:nol.photo,r:2,i:224837 -->
# <a class="item2" href="/movie/bi/mi/mediaView.naver?code=224837&amp;mid=54162#tab">예고편</a><!-- N=a:nol.trailer,r:2,i:224837 -->
# </span>
# </div>
# </dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a href="/movie/bi/mi/basic.naver?code=213406"><img alt="울프 하운드" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20220804_96/1659575707676hkSGI_JPEG/movie_image.jpg?type=m99_141_2"/></a><!-- N=a:nol.img,r:3,i:213406 -->
# </div>
# <dl class="lst_dsc">
# <dt class="tit">
# <span class="ico_rating_15">15세 관람가</span>
# <a href="/movie/bi/mi/basic.naver?code=213406">울프 하운드</a>
# <!-- N=a:nol.title,r:3,i:213406 -->
# </dt>
# <dd class="star">
# <dl class="info_star">
# <dt class="tit_t1">네티즌</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=213406#pointAfterTab"><span class="st_off"><span class="st_on" style="width:51.8%"></span></span><span class="num">5.18</span><span class="num2">참여 <em>11</em>명</span></a><!-- N=a:nol.urating -->
# </div>
# </dd>
# </dl>
# </dd>
# <dd>
# <dl class="info_txt1">
# <dt class="tit_t1">개요</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.naver?genre=19">액션</a><!-- N=a:nol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.naver?genre=14">전쟁</a><!-- N=a:nol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								130분
#
#
#
#
#
# 								<span class="split">|</span>
# 								2023.02.09 개봉
#
# 						</dd>
# <dt class="tit_t2">감독</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=459583">마이클 B. 체이트</a><!-- N=a:nol.director,r:1 -->
# </span>
# </dd>
# <dt class="tit_t3">출연</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=267440">제임스 매슬로</a><!-- N=a:nol.actor,r:1 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=205214">트레버 도노반</a><!-- N=a:nol.actor,r:2 -->
# </span>
# </dd>
# </dl>
# </dd>
# <dd class="info_t1">
# <div class="btn_area">
# <a class="btn_rsv" href="/movie/bi/mi/running.naver?code=213406">예매하기</a><!-- N=a:nol.ticket,r:3,i:213406 -->
# <a class="btn_download" href="https://serieson.naver.com/tvstore/detail.nhn?mcode=213406" target="_blank">다운로드</a>
# <span class="btn_t1">
# <a class="item1" href="/movie/bi/mi/photoView.naver?code=213406">포토보기</a><!-- N=a:nol.photo,r:3,i:213406 -->
# <a class="item2" href="/movie/bi/mi/mediaView.naver?code=213406&amp;mid=52955#tab">예고편</a><!-- N=a:nol.trailer,r:3,i:213406 -->
# </span>
# </div>
# </dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a href="/movie/bi/mi/basic.naver?code=214622"><img alt="다음 소희" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20230112_63/1673489515726qkQ2t_JPEG/movie_image.jpg?type=m99_141_2"/></a><!-- N=a:nol.img,r:4,i:214622 -->
# </div>
# <dl class="lst_dsc">
# <dt class="tit">
# <span class="ico_rating_15">15세 관람가</span>
# <a href="/movie/bi/mi/basic.naver?code=214622">다음 소희</a>
# <!-- N=a:nol.title,r:4,i:214622 -->
# </dt>
# <dd class="star">
# <dl class="info_star">
# <dt class="tit_t1">네티즌</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=214622#pointAfterTab"><span class="st_off"><span class="st_on" style="width:92.6%"></span></span><span class="num">9.26</span><span class="num2">참여 <em>636</em>명</span></a><!-- N=a:nol.urating -->
# </div>
# <span class="split">|</span>
# </dd>
# <dt class="tit_t2">기자 · 평론가</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=214622#pointExpertTab"><span class="st_off"><span class="st_on" style="width:67.3%"></span></span><span class="num">6.73</span><span class="num2">참여 <em>11</em>명</span></a><!-- N=a:nol.crating -->
# </div>
# </dd>
# </dl>
# </dd>
# <dd>
# <dl class="info_txt1">
# <dt class="tit_t1">개요</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.naver?genre=1">드라마</a><!-- N=a:nol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								138분
#
#
#
#
#
# 								<span class="split">|</span>
# 								2023.02.08 개봉
#
# 						</dd>
# <dt class="tit_t2">감독</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=136539">정주리</a><!-- N=a:nol.director,r:1 -->
# </span>
# </dd>
# <dt class="tit_t3">출연</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=1808">배두나</a><!-- N=a:nol.actor,r:1 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=424906">김시은</a><!-- N=a:nol.actor,r:2 -->
# </span>
# </dd>
# </dl>
# </dd>
# <dd class="info_t1">
# <div class="btn_area">
# <a class="btn_rsv" href="/movie/bi/mi/running.naver?code=214622">예매하기</a><!-- N=a:nol.ticket,r:4,i:214622 -->
# <span class="btn_t1">
# <a class="item1" href="/movie/bi/mi/photoView.naver?code=214622">포토보기</a><!-- N=a:nol.photo,r:4,i:214622 -->
# <a class="item2" href="/movie/bi/mi/mediaView.naver?code=214622&amp;mid=54187#tab">예고편</a><!-- N=a:nol.trailer,r:4,i:214622 -->
# </span>
# </div>
# </dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a href="/movie/bi/mi/basic.naver?code=225049"><img alt="네가 떨어뜨린 푸른 하늘" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20230202_244/1675305013428HzWd0_JPEG/movie_image.jpg?type=m99_141_2"/></a><!-- N=a:nol.img,r:5,i:225049 -->
# </div>
# <dl class="lst_dsc">
# <dt class="tit">
# <span class="ico_rating_12">12세 관람가</span>
# <a href="/movie/bi/mi/basic.naver?code=225049">네가 떨어뜨린 푸른 하늘</a>
# <!-- N=a:nol.title,r:5,i:225049 -->
# </dt>
# <dd class="star">
# <dl class="info_star">
# <dt class="tit_t1">네티즌</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=225049#pointAfterTab"><span class="st_off"><span class="st_on" style="width:66.6%"></span></span><span class="num">6.66</span><span class="num2">참여 <em>153</em>명</span></a><!-- N=a:nol.urating -->
# </div>
# <span class="split">|</span>
# </dd>
# <dt class="tit_t2">기자 · 평론가</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=225049#pointExpertTab"><span class="st_off"><span class="st_on" style="width:45.0%"></span></span><span class="num">4.50</span><span class="num2">참여 <em>4</em>명</span></a><!-- N=a:nol.crating -->
# </div>
# </dd>
# </dl>
# </dd>
# <dd>
# <dl class="info_txt1">
# <dt class="tit_t1">개요</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.naver?genre=5">멜로/로맨스</a><!-- N=a:nol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.naver?genre=18">SF</a><!-- N=a:nol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								93분
#
#
#
#
#
# 								<span class="split">|</span>
# 								2023.02.08 개봉
#
# 						</dd>
# <dt class="tit_t2">감독</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=357391">유키 사이토</a><!-- N=a:nol.director,r:1 -->
# </span>
# </dd>
# <dt class="tit_t3">출연</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=449352">후쿠모토 리코</a><!-- N=a:nol.actor,r:1 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=465993">마츠다 겐타</a><!-- N=a:nol.actor,r:2 -->
# </span>
# </dd>
# </dl>
# </dd>
# <dd class="info_t1">
# <div class="btn_area">
# <a class="btn_rsv" href="/movie/bi/mi/running.naver?code=225049">예매하기</a><!-- N=a:nol.ticket,r:5,i:225049 -->
# <span class="btn_t1">
# <a class="item1" href="/movie/bi/mi/photoView.naver?code=225049">포토보기</a><!-- N=a:nol.photo,r:5,i:225049 -->
# <a class="item2" href="/movie/bi/mi/mediaView.naver?code=225049&amp;mid=54176#tab">예고편</a><!-- N=a:nol.trailer,r:5,i:225049 -->
# </span>
# </div>
# </dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a href="/movie/bi/mi/basic.naver?code=18847"><img alt="타이타닉" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20230209_198/1675907886242jMQ8S_JPEG/movie_image.jpg?type=m99_141_2"/></a><!-- N=a:nol.img,r:6,i:18847 -->
# </div>
# <dl class="lst_dsc">
# <dt class="tit">
# <span class="ico_rating_15">15세 관람가</span>
# <a href="/movie/bi/mi/basic.naver?code=18847">타이타닉</a>
# <!-- N=a:nol.title,r:6,i:18847 -->
# </dt>
# <dd class="star">
# <dl class="info_star">
# <dt class="tit_t1">네티즌</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=18847#pointAfterTab"><span class="st_off"><span class="st_on" style="width:94.3%"></span></span><span class="num">9.43</span><span class="num2">참여 <em>24,324</em>명</span></a><!-- N=a:nol.urating -->
# </div>
# <span class="split">|</span>
# </dd>
# <dt class="tit_t2">기자 · 평론가</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=18847#pointExpertTab"><span class="st_off"><span class="st_on" style="width:95.0%"></span></span><span class="num">9.50</span><span class="num2">참여 <em>4</em>명</span></a><!-- N=a:nol.crating -->
# </div>
# </dd>
# </dl>
# </dd>
# <dd>
# <dl class="info_txt1">
# <dt class="tit_t1">개요</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.naver?genre=5">멜로/로맨스</a><!-- N=a:nol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.naver?genre=1">드라마</a><!-- N=a:nol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								195분
#
#
#
#
#
# 								<span class="split">|</span>
# 								2023.02.08 개봉
#
# 						</dd>
# <dt class="tit_t2">감독</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=621">제임스 카메론</a><!-- N=a:nol.director,r:1 -->
# </span>
# </dd>
# <dt class="tit_t3">출연</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=922">레오나르도 디카프리오</a><!-- N=a:nol.actor,r:1 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=837">케이트 윈슬렛</a><!-- N=a:nol.actor,r:2 -->
# </span>
# </dd>
# </dl>
# </dd>
# <dd class="info_t1">
# <div class="btn_area">
# <a class="btn_rsv" href="/movie/bi/mi/running.naver?code=18847">예매하기</a><!-- N=a:nol.ticket,r:6,i:18847 -->
# <a class="btn_download" href="https://serieson.naver.com/tvstore/detail.nhn?mcode=18847" target="_blank">다운로드</a>
# <span class="btn_t1">
# <a class="item1" href="/movie/bi/mi/photoView.naver?code=18847">포토보기</a><!-- N=a:nol.photo,r:6,i:18847 -->
# <a class="item2" href="/movie/bi/mi/mediaView.naver?code=18847&amp;mid=54244#tab">예고편</a><!-- N=a:nol.trailer,r:6,i:18847 -->
# <a class="item4" href="/movie/bi/mi/mediaView.naver?code=18847&amp;mid=37710#tab">메이킹</a><!-- N=a:nol.making,r:6,i:18847 -->
# <a class="item5" href="/movie/bi/mi/mediaView.naver?code=18847&amp;mid=17475#tab">인터뷰</a><!-- N=a:nol.interview,r:6,i:18847 -->
# </span>
# </div>
# </dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a href="/movie/bi/mi/basic.naver?code=224836"><img alt="어쩌면 우린 헤어졌는지 모른다" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20230119_219/1674119535097aG5TR_JPEG/movie_image.jpg?type=m99_141_2"/></a><!-- N=a:nol.img,r:7,i:224836 -->
# </div>
# <dl class="lst_dsc">
# <dt class="tit">
# <span class="ico_rating_12">12세 관람가</span>
# <a href="/movie/bi/mi/basic.naver?code=224836">어쩌면 우린 헤어졌는지 모른다</a>
# <!-- N=a:nol.title,r:7,i:224836 -->
# </dt>
# <dd class="star">
# <dl class="info_star">
# <dt class="tit_t1">네티즌</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=224836#pointAfterTab"><span class="st_off"><span class="st_on" style="width:86.5%"></span></span><span class="num">8.65</span><span class="num2">참여 <em>108</em>명</span></a><!-- N=a:nol.urating -->
# </div>
# <span class="split">|</span>
# </dd>
# <dt class="tit_t2">기자 · 평론가</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=224836#pointExpertTab"><span class="st_off"><span class="st_on" style="width:56.7%"></span></span><span class="num">5.67</span><span class="num2">참여 <em>6</em>명</span></a><!-- N=a:nol.crating -->
# </div>
# </dd>
# </dl>
# </dd>
# <dd>
# <dl class="info_txt1">
# <dt class="tit_t1">개요</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.naver?genre=1">드라마</a><!-- N=a:nol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								103분
#
#
#
#
#
# 								<span class="split">|</span>
# 								2023.02.08 개봉
#
# 						</dd>
# <dt class="tit_t2">감독</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=174462">형슬우</a><!-- N=a:nol.director,r:1 -->
# </span>
# </dd>
# <dt class="tit_t3">출연</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=338646">이동휘</a><!-- N=a:nol.actor,r:1 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=243562">정은채</a><!-- N=a:nol.actor,r:2 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=404681">강길우</a><!-- N=a:nol.actor,r:3 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=392458">정다은</a><!-- N=a:nol.actor,r:4 -->
# </span>
# </dd>
# </dl>
# </dd>
# <dd class="info_t1">
# <div class="btn_area">
# <a class="btn_rsv" href="/movie/bi/mi/running.naver?code=224836">예매하기</a><!-- N=a:nol.ticket,r:7,i:224836 -->
# <span class="btn_t1">
# <a class="item1" href="/movie/bi/mi/photoView.naver?code=224836">포토보기</a><!-- N=a:nol.photo,r:7,i:224836 -->
# <a class="item2" href="/movie/bi/mi/mediaView.naver?code=224836&amp;mid=54243#tab">예고편</a><!-- N=a:nol.trailer,r:7,i:224836 -->
# <a class="item3" href="/movie/bi/mi/mediaView.naver?code=224836&amp;mid=54194#tab">뮤직비디오</a><!-- N=a:nol.mv,r:7,i:224836 -->
# </span>
# </div>
# </dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a href="/movie/bi/mi/basic.naver?code=224579"><img alt="우리 사랑이 향기로 남을 때" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20230131_259/16751322045282PolH_JPEG/movie_image.jpg?type=m99_141_2"/></a><!-- N=a:nol.img,r:8,i:224579 -->
# </div>
# <dl class="lst_dsc">
# <dt class="tit">
# <span class="ico_rating_15">15세 관람가</span>
# <a href="/movie/bi/mi/basic.naver?code=224579">우리 사랑이 향기로 남을 때</a>
# <!-- N=a:nol.title,r:8,i:224579 -->
# </dt>
# <dd class="star">
# <dl class="info_star">
# <dt class="tit_t1">네티즌</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=224579#pointAfterTab"><span class="st_off"><span class="st_on" style="width:69.7%"></span></span><span class="num">6.97</span><span class="num2">참여 <em>203</em>명</span></a><!-- N=a:nol.urating -->
# </div>
# <span class="split">|</span>
# </dd>
# <dt class="tit_t2">기자 · 평론가</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=224579#pointExpertTab"><span class="st_off"><span class="st_on" style="width:40.0%"></span></span><span class="num">4.00</span><span class="num2">참여 <em>1</em>명</span></a><!-- N=a:nol.crating -->
# </div>
# </dd>
# </dl>
# </dd>
# <dd>
# <dl class="info_txt1">
# <dt class="tit_t1">개요</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.naver?genre=5">멜로/로맨스</a><!-- N=a:nol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.naver?genre=11">코미디</a><!-- N=a:nol.genre,r:2 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.naver?genre=1">드라마</a><!-- N=a:nol.genre,r:3 -->
# </span>
# <span class="split">|</span>
# 								108분
#
#
#
#
#
# 								<span class="split">|</span>
# 								2023.02.08 개봉
#
# 						</dd>
# <dt class="tit_t2">감독</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=86136">임성용</a><!-- N=a:nol.director,r:1 -->
# </span>
# </dd>
# <dt class="tit_t3">출연</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=170357">윤시윤</a><!-- N=a:nol.actor,r:1 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=397374">설인아</a><!-- N=a:nol.actor,r:2 -->
# </span>
# </dd>
# </dl>
# </dd>
# <dd class="info_t1">
# <div class="btn_area">
# <a class="btn_rsv" href="/movie/bi/mi/running.naver?code=224579">예매하기</a><!-- N=a:nol.ticket,r:8,i:224579 -->
# <span class="btn_t1">
# <a class="item1" href="/movie/bi/mi/photoView.naver?code=224579">포토보기</a><!-- N=a:nol.photo,r:8,i:224579 -->
# <a class="item2" href="/movie/bi/mi/mediaView.naver?code=224579&amp;mid=54262#tab">예고편</a><!-- N=a:nol.trailer,r:8,i:224579 -->
# <a class="item3" href="/movie/bi/mi/mediaView.naver?code=224579&amp;mid=54216#tab">뮤직비디오</a><!-- N=a:nol.mv,r:8,i:224579 -->
# </span>
# </div>
# </dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a href="/movie/bi/mi/basic.naver?code=213400"><img alt="트윈" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20230119_172/1674119298055hcfrt_JPEG/movie_image.jpg?type=m99_141_2"/></a><!-- N=a:nol.img,r:9,i:213400 -->
# </div>
# <dl class="lst_dsc">
# <dt class="tit">
# <span class="ico_rating_15">15세 관람가</span>
# <a href="/movie/bi/mi/basic.naver?code=213400">트윈</a>
# <!-- N=a:nol.title,r:9,i:213400 -->
# </dt>
# <dd class="star">
# <dl class="info_star">
# <dt class="tit_t1">네티즌</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=213400#pointAfterTab"><span class="st_off"><span class="st_on" style="width:59.2%"></span></span><span class="num">5.92</span><span class="num2">참여 <em>53</em>명</span></a><!-- N=a:nol.urating -->
# </div>
# <span class="split">|</span>
# </dd>
# <dt class="tit_t2">기자 · 평론가</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=213400#pointExpertTab"><span class="st_off"><span class="st_on" style="width:46.7%"></span></span><span class="num">4.67</span><span class="num2">참여 <em>3</em>명</span></a><!-- N=a:nol.crating -->
# </div>
# </dd>
# </dl>
# </dd>
# <dd>
# <dl class="info_txt1">
# <dt class="tit_t1">개요</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.naver?genre=4">공포</a><!-- N=a:nol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								108분
#
#
#
#
#
# 								<span class="split">|</span>
# 								2023.02.08 개봉
#
# 						</dd>
# <dt class="tit_t2">감독</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=330220">타넬리 무스토넨</a><!-- N=a:nol.director,r:1 -->
# </span>
# </dd>
# <dt class="tit_t3">출연</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=92413">테레사 팔머</a><!-- N=a:nol.actor,r:1 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=248088">스티븐 크리</a><!-- N=a:nol.actor,r:2 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=462666">트리스탄 루게리</a><!-- N=a:nol.actor,r:3 -->
# </span>
# </dd>
# </dl>
# </dd>
# <dd class="info_t1">
# <div class="btn_area">
# <a class="btn_rsv" href="/movie/bi/mi/running.naver?code=213400">예매하기</a><!-- N=a:nol.ticket,r:9,i:213400 -->
# <span class="btn_t1">
# <a class="item1" href="/movie/bi/mi/photoView.naver?code=213400">포토보기</a><!-- N=a:nol.photo,r:9,i:213400 -->
# <a class="item2" href="/movie/bi/mi/mediaView.naver?code=213400&amp;mid=54198#tab">예고편</a><!-- N=a:nol.trailer,r:9,i:213400 -->
# </span>
# </div>
# </dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a href="/movie/bi/mi/basic.naver?code=196043"><img alt="궁지에 몰린 쥐는 치즈 꿈을 꾼다" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20230120_202/1674190669178kKNg8_JPEG/movie_image.jpg?type=m99_141_2"/></a><!-- N=a:nol.img,r:10,i:196043 -->
# </div>
# <dl class="lst_dsc">
# <dt class="tit">
# <span class="ico_rating_18">청소년 관람불가</span>
# <a href="/movie/bi/mi/basic.naver?code=196043">궁지에 몰린 쥐는 치즈 꿈을 꾼다</a>
# <!-- N=a:nol.title,r:10,i:196043 -->
# </dt>
# <dd class="star">
# <dl class="info_star">
# <dt class="tit_t1">네티즌</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=196043#pointAfterTab"><span class="st_off"><span class="st_on" style="width:72.4%"></span></span><span class="num">7.24</span><span class="num2">참여 <em>17</em>명</span></a><!-- N=a:nol.urating -->
# </div>
# <span class="split">|</span>
# </dd>
# <dt class="tit_t2">기자 · 평론가</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=196043#pointExpertTab"><span class="st_off"><span class="st_on" style="width:53.3%"></span></span><span class="num">5.33</span><span class="num2">참여 <em>3</em>명</span></a><!-- N=a:nol.crating -->
# </div>
# </dd>
# </dl>
# </dd>
# <dd>
# <dl class="info_txt1">
# <dt class="tit_t1">개요</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.naver?genre=1">드라마</a><!-- N=a:nol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.naver?genre=5">멜로/로맨스</a><!-- N=a:nol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								131분
#
#
#
#
#
# 								<span class="split">|</span>
# 								2023.02.08 개봉
#
# 						</dd>
# <dt class="tit_t2">감독</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=2236">유키사다 이사오</a><!-- N=a:nol.director,r:1 -->
# </span>
# </dd>
# <dt class="tit_t3">출연</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=243167">오쿠라 타다요시</a><!-- N=a:nol.actor,r:1 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=393822">나리타 료</a><!-- N=a:nol.actor,r:2 -->
# </span>
# </dd>
# </dl>
# </dd>
# <dd class="info_t1">
# <div class="btn_area">
# <a class="btn_rsv" href="/movie/bi/mi/running.naver?code=196043">예매하기</a><!-- N=a:nol.ticket,r:10,i:196043 -->
# <span class="btn_t1">
# <a class="item1" href="/movie/bi/mi/photoView.naver?code=196043">포토보기</a><!-- N=a:nol.photo,r:10,i:196043 -->
# <a class="item2" href="/movie/bi/mi/mediaView.naver?code=196043&amp;mid=54138#tab">예고편</a><!-- N=a:nol.trailer,r:10,i:196043 -->
# </span>
# </div>
# </dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a href="/movie/bi/mi/basic.naver?code=224905"><img alt="디텍티브 나이트: 가면의 밤" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20230120_234/1674184984171pLX9O_JPEG/movie_image.jpg?type=m99_141_2"/></a><!-- N=a:nol.img,r:11,i:224905 -->
# </div>
# <dl class="lst_dsc">
# <dt class="tit">
# <span class="ico_rating_15">15세 관람가</span>
# <a href="/movie/bi/mi/basic.naver?code=224905">디텍티브 나이트: 가면의 밤</a>
# <!-- N=a:nol.title,r:11,i:224905 -->
# </dt>
# <dd class="star">
# <dl class="info_star">
# <dt class="tit_t1">네티즌</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=224905#pointAfterTab"><span class="st_off"><span class="st_on" style="width:27.8%"></span></span><span class="num">2.78</span><span class="num2">참여 <em>9</em>명</span></a><!-- N=a:nol.urating -->
# </div>
# </dd>
# </dl>
# </dd>
# <dd>
# <dl class="info_txt1">
# <dt class="tit_t1">개요</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.naver?genre=16">범죄</a><!-- N=a:nol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.naver?genre=19">액션</a><!-- N=a:nol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								105분
#
#
#
#
#
# 								<span class="split">|</span>
# 								2023.02.08 개봉
#
# 						</dd>
# <dt class="tit_t2">감독</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=344878">에드워드 드레이크</a><!-- N=a:nol.director,r:1 -->
# </span>
# </dd>
# <dt class="tit_t3">출연</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=187">브루스 윌리스</a><!-- N=a:nol.actor,r:1 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=2360">로슬린 먼로</a><!-- N=a:nol.actor,r:2 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=15674">지미 장 루이스</a><!-- N=a:nol.actor,r:3 -->
# </span>
# </dd>
# </dl>
# </dd>
# <dd class="info_t1">
# <div class="btn_area">
# <a class="btn_rsv" href="/movie/bi/mi/running.naver?code=224905">예매하기</a><!-- N=a:nol.ticket,r:11,i:224905 -->
# <span class="btn_t1">
# <a class="item1" href="/movie/bi/mi/photoView.naver?code=224905">포토보기</a><!-- N=a:nol.photo,r:11,i:224905 -->
# <a class="item2" href="/movie/bi/mi/mediaView.naver?code=224905&amp;mid=54153#tab">예고편</a><!-- N=a:nol.trailer,r:11,i:224905 -->
# </span>
# </div>
# </dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a href="/movie/bi/mi/basic.naver?code=217509"><img alt="성스러운 거미" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20230125_267/1674630072511MIxhn_JPEG/movie_image.jpg?type=m99_141_2"/></a><!-- N=a:nol.img,r:12,i:217509 -->
# </div>
# <dl class="lst_dsc">
# <dt class="tit">
# <span class="ico_rating_18">청소년 관람불가</span>
# <a href="/movie/bi/mi/basic.naver?code=217509">성스러운 거미</a>
# <!-- N=a:nol.title,r:12,i:217509 -->
# </dt>
# <dd class="star">
# <dl class="info_star">
# <dt class="tit_t1">네티즌</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=217509#pointAfterTab"><span class="st_off"><span class="st_on" style="width:81.4%"></span></span><span class="num">8.14</span><span class="num2">참여 <em>58</em>명</span></a><!-- N=a:nol.urating -->
# </div>
# <span class="split">|</span>
# </dd>
# <dt class="tit_t2">기자 · 평론가</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=217509#pointExpertTab"><span class="st_off"><span class="st_on" style="width:70.0%"></span></span><span class="num">7.00</span><span class="num2">참여 <em>8</em>명</span></a><!-- N=a:nol.crating -->
# </div>
# </dd>
# </dl>
# </dd>
# <dd>
# <dl class="info_txt1">
# <dt class="tit_t1">개요</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.naver?genre=16">범죄</a><!-- N=a:nol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.naver?genre=7">스릴러</a><!-- N=a:nol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								118분
#
#
#
#
#
# 								<span class="split">|</span>
# 								2023.02.08 개봉
#
# 						</dd>
# <dt class="tit_t2">감독</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=165819">알리 아바시</a><!-- N=a:nol.director,r:1 -->
# </span>
# </dd>
# <dt class="tit_t3">출연</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=415400">자흐라 아미르 에브라히미</a><!-- N=a:nol.actor,r:1 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=461899">메흐디 바제스타니</a><!-- N=a:nol.actor,r:2 -->
# </span>
# </dd>
# </dl>
# </dd>
# <dd class="info_t1">
# <div class="btn_area">
# <a class="btn_rsv" href="/movie/bi/mi/running.naver?code=217509">예매하기</a><!-- N=a:nol.ticket,r:12,i:217509 -->
# <span class="btn_t1">
# <a class="item1" href="/movie/bi/mi/photoView.naver?code=217509">포토보기</a><!-- N=a:nol.photo,r:12,i:217509 -->
# <a class="item2" href="/movie/bi/mi/mediaView.naver?code=217509&amp;mid=54241#tab">예고편</a><!-- N=a:nol.trailer,r:12,i:217509 -->
# </span>
# </div>
# </dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a href="/movie/bi/mi/basic.naver?code=217482"><img alt="안녕, 소중한 사람" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20230112_244/1673503968731uegRr_JPEG/movie_image.jpg?type=m99_141_2"/></a><!-- N=a:nol.img,r:13,i:217482 -->
# </div>
# <dl class="lst_dsc">
# <dt class="tit">
# <span class="ico_rating_15">15세 관람가</span>
# <a href="/movie/bi/mi/basic.naver?code=217482">안녕, 소중한 사람</a>
# <!-- N=a:nol.title,r:13,i:217482 -->
# </dt>
# <dd class="star">
# <dl class="info_star">
# <dt class="tit_t1">네티즌</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=217482#pointAfterTab"><span class="st_off"><span class="st_on" style="width:88.5%"></span></span><span class="num">8.85</span><span class="num2">참여 <em>13</em>명</span></a><!-- N=a:nol.urating -->
# </div>
# <span class="split">|</span>
# </dd>
# <dt class="tit_t2">기자 · 평론가</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=217482#pointExpertTab"><span class="st_off"><span class="st_on" style="width:66.7%"></span></span><span class="num">6.67</span><span class="num2">참여 <em>6</em>명</span></a><!-- N=a:nol.crating -->
# </div>
# </dd>
# </dl>
# </dd>
# <dd>
# <dl class="info_txt1">
# <dt class="tit_t1">개요</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.naver?genre=1">드라마</a><!-- N=a:nol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								123분
#
#
#
#
#
# 								<span class="split">|</span>
# 								2023.02.08 개봉
#
# 						</dd>
# <dt class="tit_t2">감독</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=154032">에밀리 아테프</a><!-- N=a:nol.director,r:1 -->
# </span>
# </dd>
# <dt class="tit_t3">출연</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=276720">비키 크립스</a><!-- N=a:nol.actor,r:1 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=48327">가스파르 울리엘</a><!-- N=a:nol.actor,r:2 -->
# </span>
# </dd>
# </dl>
# </dd>
# <dd class="info_t1">
# <div class="btn_area">
# <a class="btn_rsv" href="/movie/bi/mi/running.naver?code=217482">예매하기</a><!-- N=a:nol.ticket,r:13,i:217482 -->
# <span class="btn_t1">
# <a class="item1" href="/movie/bi/mi/photoView.naver?code=217482">포토보기</a><!-- N=a:nol.photo,r:13,i:217482 -->
# <a class="item2" href="/movie/bi/mi/mediaView.naver?code=217482&amp;mid=54158#tab">예고편</a><!-- N=a:nol.trailer,r:13,i:217482 -->
# <a class="item3" href="/movie/bi/mi/mediaView.naver?code=217482&amp;mid=54189#tab">뮤직비디오</a><!-- N=a:nol.mv,r:13,i:217482 -->
# </span>
# </div>
# </dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a href="/movie/bi/mi/basic.naver?code=10453"><img alt="졸업" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20200123_222/15797438220259L2PK_JPEG/movie_image.jpg?type=m99_141_2"/></a><!-- N=a:nol.img,r:14,i:10453 -->
# </div>
# <dl class="lst_dsc">
# <dt class="tit">
# <span class="ico_rating_15">15세 관람가</span>
# <a href="/movie/bi/mi/basic.naver?code=10453">졸업</a>
# <!-- N=a:nol.title,r:14,i:10453 -->
# </dt>
# <dd class="star">
# <dl class="info_star">
# <dt class="tit_t1">네티즌</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=10453#pointAfterTab"><span class="st_off"><span class="st_on" style="width:84.8%"></span></span><span class="num">8.48</span><span class="num2">참여 <em>473</em>명</span></a><!-- N=a:nol.urating -->
# </div>
# </dd>
# </dl>
# </dd>
# <dd>
# <dl class="info_txt1">
# <dt class="tit_t1">개요</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.naver?genre=1">드라마</a><!-- N=a:nol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.naver?genre=11">코미디</a><!-- N=a:nol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								106분
#
#
#
#
#
# 								<span class="split">|</span>
# 								2023.02.08 개봉
#
# 						</dd>
# <dt class="tit_t2">감독</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=1107">마이크 니콜스</a><!-- N=a:nol.director,r:1 -->
# </span>
# </dd>
# <dt class="tit_t3">출연</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=2552">앤 밴크로프트</a><!-- N=a:nol.actor,r:1 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=376">더스틴 호프만</a><!-- N=a:nol.actor,r:2 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=2403">캐서린 로스</a><!-- N=a:nol.actor,r:3 -->
# </span>
# </dd>
# </dl>
# </dd>
# <dd class="info_t1">
# <div class="btn_area">
# <a class="btn_rsv" href="/movie/bi/mi/running.naver?code=10453">예매하기</a><!-- N=a:nol.ticket,r:14,i:10453 -->
# <a class="btn_download" href="https://serieson.naver.com/tvstore/detail.nhn?mcode=10453" target="_blank">다운로드</a>
# <span class="btn_t1">
# <a class="item1" href="/movie/bi/mi/photoView.naver?code=10453">포토보기</a><!-- N=a:nol.photo,r:14,i:10453 -->
# <a class="item2" href="/movie/bi/mi/mediaView.naver?code=10453&amp;mid=45226#tab">예고편</a><!-- N=a:nol.trailer,r:14,i:10453 -->
# <a class="item4" href="/movie/bi/mi/mediaView.naver?code=10453&amp;mid=45299#tab">메이킹</a><!-- N=a:nol.making,r:14,i:10453 -->
# </span>
# </div>
# </dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a href="/movie/bi/mi/basic.naver?code=224833"><img alt="몬스터 하우스2: 인비져블 피닉스" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20230120_114/16742051296728IGUd_JPEG/movie_image.jpg?type=m99_141_2"/></a><!-- N=a:nol.img,r:15,i:224833 -->
# </div>
# <dl class="lst_dsc">
# <dt class="tit">
# <span class="ico_rating_all">전체 관람가</span>
# <a href="/movie/bi/mi/basic.naver?code=224833">몬스터 하우스2: 인비져블 피닉스</a>
# <!-- N=a:nol.title,r:15,i:224833 -->
# </dt>
# <dd class="star">
# <dl class="info_star">
# <dt class="tit_t1">네티즌</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=224833#pointAfterTab"><span class="st_off"><span class="st_on" style="width:76.8%"></span></span><span class="num">7.68</span><span class="num2">참여 <em>19</em>명</span></a><!-- N=a:nol.urating -->
# </div>
# <span class="split">|</span>
# </dd>
# <dt class="tit_t2">기자 · 평론가</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=224833#pointExpertTab"><span class="st_off"><span class="st_on" style="width:70.0%"></span></span><span class="num">7.00</span><span class="num2">참여 <em>1</em>명</span></a><!-- N=a:nol.crating -->
# </div>
# </dd>
# </dl>
# </dd>
# <dd>
# <dl class="info_txt1">
# <dt class="tit_t1">개요</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.naver?genre=15">애니메이션</a><!-- N=a:nol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.naver?genre=2">판타지</a><!-- N=a:nol.genre,r:2 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.naver?genre=6">모험</a><!-- N=a:nol.genre,r:3 -->
# </span>
# <span class="split">|</span>
# 								85분
#
#
#
#
#
# 								<span class="split">|</span>
# 								2023.02.02 개봉
#
# 						</dd>
# <dt class="tit_t2">감독</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=349428">데니스 체르노프</a><!-- N=a:nol.director,r:1 -->
# </span>
# </dd>
# </dl>
# </dd>
# <dd class="info_t1">
# <div class="btn_area">
# <a class="btn_rsv" href="/movie/bi/mi/running.naver?code=224833">예매하기</a><!-- N=a:nol.ticket,r:15,i:224833 -->
# <span class="btn_t1">
# <a class="item1" href="/movie/bi/mi/photoView.naver?code=224833">포토보기</a><!-- N=a:nol.photo,r:15,i:224833 -->
# <a class="item2" href="/movie/bi/mi/mediaView.naver?code=224833&amp;mid=54134#tab">예고편</a><!-- N=a:nol.trailer,r:15,i:224833 -->
# </span>
# </div>
# </dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a href="/movie/bi/mi/basic.naver?code=224606"><img alt="극장판 전생했더니 슬라임이었던 건에 대하여: 홍련의 인연편" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20230104_109/1672816444217hLBu4_JPEG/movie_image.jpg?type=m99_141_2"/></a><!-- N=a:nol.img,r:16,i:224606 -->
# </div>
# <dl class="lst_dsc">
# <dt class="tit">
# <span class="ico_rating_15">15세 관람가</span>
# <a href="/movie/bi/mi/basic.naver?code=224606">극장판 전생했더니 슬라임이었던 건에 대하여: 홍련의 인연편</a>
# <!-- N=a:nol.title,r:16,i:224606 -->
# </dt>
# <dd class="star">
# <dl class="info_star">
# <dt class="tit_t1">네티즌</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=224606#pointAfterTab"><span class="st_off"><span class="st_on" style="width:74.8%"></span></span><span class="num">7.48</span><span class="num2">참여 <em>50</em>명</span></a><!-- N=a:nol.urating -->
# </div>
# <span class="split">|</span>
# </dd>
# <dt class="tit_t2">기자 · 평론가</dt>
# <dd>
# <div class="star_t1">
# ...
# <dt class="tit">
# <a href="/movie/bi/mi/basic.naver?code=11474">박서방</a>
# <!-- N=a:nol.title,r:100,i:11474 -->
# </dt>
# <dd class="star">
# <dl class="info_star">
# <dt class="tit_t1">네티즌</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=11474#pointAfterTab"><span class="st_off"><span class="st_on" style="width:90.9%"></span></span><span class="num">9.09</span><span class="num2">참여 <em>23</em>명</span></a><!-- N=a:nol.urating -->
# </div>
# </dd>
# </dl>
# </dd>
# <dd>
# <dl class="info_txt1">
# <dt class="tit_t1">개요</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.naver?genre=12">가족</a><!-- N=a:nol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.naver?genre=1">드라마</a><!-- N=a:nol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								140분
#
#
#
#
#
# 								<span class="split">|</span>
# 								1960.10.05 개봉
#
# 						</dd>
# <dt class="tit_t2">감독</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=18962">강대진</a><!-- N=a:nol.director,r:1 -->
# </span>
# </dd>
# <dt class="tit_t3">출연</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=40872">김승호</a><!-- N=a:nol.actor,r:1 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=18960">조미령</a><!-- N=a:nol.actor,r:2 -->
# </span>
# </dd>
# </dl>
# </dd>
# <dd class="info_t1">
# <div class="btn_area">
# <a class="btn_rsv" href="/movie/bi/mi/running.naver?code=11474">예매하기</a><!-- N=a:nol.ticket,r:100,i:11474 -->
# <span class="btn_t1">
# <a class="item1" href="/movie/bi/mi/photoView.naver?code=11474">포토보기</a><!-- N=a:nol.photo,r:100,i:11474 -->
# </span>
# </div>
# </dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a href="/movie/bi/mi/basic.naver?code=10243"><img alt="북북서로 진로를 돌려라" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20180807_223/1533618155212UMhmv_JPEG/movie_image.jpg?type=m99_141_2"/></a><!-- N=a:nol.img,r:101,i:10243 -->
# </div>
# <dl class="lst_dsc">
# <dt class="tit">
# <span class="ico_rating_12">12세 관람가</span>
# <a href="/movie/bi/mi/basic.naver?code=10243">북북서로 진로를 돌려라</a>
# <!-- N=a:nol.title,r:101,i:10243 -->
# </dt>
# <dd class="star">
# <dl class="info_star">
# <dt class="tit_t1">네티즌</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=10243#pointAfterTab"><span class="st_off"><span class="st_on" style="width:86.7%"></span></span><span class="num">8.67</span><span class="num2">참여 <em>212</em>명</span></a><!-- N=a:nol.urating -->
# </div>
# </dd>
# </dl>
# </dd>
# <dd>
# <dl class="info_txt1">
# <dt class="tit_t1">개요</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.naver?genre=6">모험</a><!-- N=a:nol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.naver?genre=7">스릴러</a><!-- N=a:nol.genre,r:2 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.naver?genre=5">멜로/로맨스</a><!-- N=a:nol.genre,r:3 -->
# </span>
# <span class="split">|</span>
# 								136분
#
#
#
#
#
# 								<span class="split">|</span>
# 								1960.10.01 개봉
#
# 						</dd>
# <dt class="tit_t2">감독</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=48">알프레드 히치콕</a><!-- N=a:nol.director,r:1 -->
# </span>
# </dd>
# <dt class="tit_t3">출연</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=217">캐리 그랜트</a><!-- N=a:nol.actor,r:1 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=4423">에바 마리 세인트</a><!-- N=a:nol.actor,r:2 -->,
#
# 									<a href="/movie/bi/pi/basic.naver?code=632">제임스 메이슨</a><!-- N=a:nol.actor,r:3 -->
# </span>
# </dd>
# </dl>
# </dd>
# <dd class="info_t1">
# <div class="btn_area">
# <a class="btn_rsv" href="/movie/bi/mi/running.naver?code=10243">예매하기</a><!-- N=a:nol.ticket,r:101,i:10243 -->
# <a class="btn_download" href="https://serieson.naver.com/tvstore/detail.nhn?mcode=10243" target="_blank">다운로드</a>
# <span class="btn_t1">
# <a class="item1" href="/movie/bi/mi/photoView.naver?code=10243">포토보기</a><!-- N=a:nol.photo,r:101,i:10243 -->
# </span>
# </div>
# </dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a href="/movie/bi/mi/basic.naver?code=20324"><img alt="수색자" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20111221_288/1324451033289kl9Gv_JPEG/movie_image.jpg?type=m99_141_2"/></a><!-- N=a:nol.img,r:102,i:20324 -->
# </div>
# <dl class="lst_dsc">
# <dt class="tit">
# <span class="ico_rating_12">12세 관람가</span>
# <a href="/movie/bi/mi/basic.naver?code=20324">수색자</a>
# <!-- N=a:nol.title,r:102,i:20324 -->
# </dt>
# <dd class="star">
# <dl class="info_star">
# <dt class="tit_t1">네티즌</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=20324#pointAfterTab"><span class="st_off"><span class="st_on" style="width:83.6%"></span></span><span class="num">8.36</span><span class="num2">참여 <em>36</em>명</span></a><!-- N=a:nol.urating -->
# </div>
# </dd>
# </dl>
# </dd>
# <dd>
# <dl class="info_txt1">
# <dt class="tit_t1">개요</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.naver?genre=6">모험</a><!-- N=a:nol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.naver?genre=1">드라마</a><!-- N=a:nol.genre,r:2 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.naver?genre=3">서부</a><!-- N=a:nol.genre,r:3 -->
# </span>
# <span class="split">|</span>
# 								119분
#
#
#
#
#
# 								<span class="split">|</span>
# 								1957.12.07 개봉
#
# 						</dd>
# <dt class="tit_t2">감독</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=2639">존 포드</a><!-- N=a:nol.director,r:1 -->
# </span>
# </dd>
# <dt class="tit_t3">출연</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=784">존 웨인</a><!-- N=a:nol.actor,r:1 -->
# </span>
# </dd>
# </dl>
# </dd>
# <dd class="info_t1">
# <div class="btn_area">
# <a class="btn_rsv" href="/movie/bi/mi/running.naver?code=20324">예매하기</a><!-- N=a:nol.ticket,r:102,i:20324 -->
# <a class="btn_download" href="https://serieson.naver.com/tvstore/detail.nhn?mcode=20324" target="_blank">다운로드</a>
# <span class="btn_t1">
# <a class="item1" href="/movie/bi/mi/photoView.naver?code=20324">포토보기</a><!-- N=a:nol.photo,r:102,i:20324 -->
# </span>
# </div>
# </dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a href="/movie/bi/mi/basic.naver?code=13196"><img alt="애정" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20111221_34/1324454929742q9rxp_JPEG/movie_image.jpg?type=m99_141_2"/></a><!-- N=a:nol.img,r:103,i:13196 -->
# </div>
# <dl class="lst_dsc">
# <dt class="tit">
# <a href="/movie/bi/mi/basic.naver?code=13196">애정</a>
# <!-- N=a:nol.title,r:103,i:13196 -->
# </dt>
# <dd class="star">
# <dl class="info_star">
# <dt class="tit_t1">네티즌</dt>
# <dd>
# <div class="star_t1">
# <a href="/movie/bi/mi/point.naver?code=13196#pointAfterTab"><span class="st_off"><span class="st_on" style="width:80.0%"></span></span><span class="num">8.00</span><span class="num2">참여 <em>2</em>명</span></a><!-- N=a:nol.urating -->
# </div>
# </dd>
# </dl>
# </dd>
# <dd>
# <dl class="info_txt1">
# <dt class="tit_t1">개요</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.naver?genre=1">드라마</a><!-- N=a:nol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.naver?genre=12">가족</a><!-- N=a:nol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								128분
#
#
#
#
#
# 								<span class="split">|</span>
# 								1956.12.07 개봉
#
# 						</dd>
# <dt class="tit_t2">감독</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=30583">클라렌스 브라운</a><!-- N=a:nol.director,r:1 -->
# </span>
# </dd>
# <dt class="tit_t3">출연</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.naver?code=514">그레고리 펙</a><!-- N=a:nol.actor,r:1 -->
# </span>
# </dd>
# </dl>
# </dd>
# <dd class="info_t1">
# <div class="btn_area">
# <a class="btn_rsv" href="/movie/bi/mi/running.naver?code=13196">예매하기</a><!-- N=a:nol.ticket,r:103,i:13196 -->
# <span class="btn_t1">
# <a class="item1" href="/movie/bi/mi/photoView.naver?code=13196">포토보기</a><!-- N=a:nol.photo,r:103,i:13196 -->
# </span>
# </div>
# </dd>
# </dl>
# </li>
# </ul>
# </div>
# </div>
# <p class="db_bottom">영화정보의 수정이나 신규생성이 필요한 경우 고객센터 DB제보로 문의해주세요.<a class="qna" href="https://help.naver.com/support/alias/contents2/movie/movie_1.naver" target="_blank">고객센터 DB제보 문의하기</a><!-- N=a:btm.dbr --></p>
# <p class="mod_nanum"><span class="ic_warning"></span>본 페이지는 나눔글꼴에 최적화 되어있습니다.<a href="http://hangeul.naver.com/font" target="_blank">나눔글꼴설치</a></p>
# </div>
# <div class="staticbanner" id="floatingTopAnchor" style="bottom:40px">
# <a href="#u_skip" title="맨위로"><img alt="맨위로" height="35" src="https://ssl.pstatic.net/static/movie/2012/08/btn_top.png" width="33"/></a><!-- N=a:btm.top -->
# </div>
# <script type="text/javascript">
# jindo.$Fn(function () {
#     var welTopAnchor = jindo.$Element('floatingTopAnchor');
#     var welContent = jindo.$Element('content');
#     var nTopMargin = 342 + welTopAnchor.height();
#     var nMaxY;
#     var nMinY = 61;
#     var oFloatingLayer = new jindo.FloatingLayer(welTopAnchor).attach({
#         beforeMove: function (oEvent) {
#             // 상단 limit
#             nMaxY = welContent.height() - nTopMargin;
#             if (oEvent.nY > nMaxY) {
#                 oEvent.nY = nMaxY;
#             }
#
#              // 하단 limit
#             if (oEvent.nY < nMinY) {
#                 oEvent.nY = nMinY;
#             }
#         }
#     });
# }).attach(window, 'load');
# </script>
# </div>
# <!-- //content -->
# <script type="text/javascript">
# 	var nsc = "movie.running";
# </script>
# </div>
# <!-- //container -->
# <!-- footer -->
# <div id="footer">
# <div class="in_footer">
# <div class="foot_con">
# <ul>
# <li class="first"><a href="http://www.naver.com/rules/service.html" target="_blank">이용약관</a><!-- N=a:fot.agreement --></li>
# <li><a href="http://www.naver.com/rules/privacy.html" target="_blank"><strong>개인정보처리방침</strong></a><!-- N=a:fot.privacy --></li>
# <li><a href="http://www.naver.com/rules/disclaimer.html" target="_blank">책임의 한계와 법적고지</a><!-- N=a:fot.disclaimer --></li>
# <li><a href="https://help.naver.com/support/service/main.nhn?serviceNo=800" target="_blank">영화 고객센터</a><!-- N=a:fot.help --></li>
# </ul>
# <p class="info">본 콘텐츠의 저작권은 저작권자 또는 제공처에 있으며, 이를 무단 이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.</p>
# <p class="info">
# 					사업자등록번호 : 220-81-62517<span>통신판매업 신고번호</span> : 경기성남 제 2006 - 692호<span>대표이사 : 최수연</span><span><a href="http://www.ftc.go.kr/info/bizinfo/communicationList.jsp">사업자등록정보 확인</a><!-- N=a:fot.bizinfo --></span><br/>
# 					주소 : 경기도 성남시 분당구 정자일로 95, NAVER 1784, 13561 <span>대표전화 : 1588-3820</span>
# </p>
# <address>
# <a class="logo" href="https://www.navercorp.com/" target="_blank"><img alt="NAVER" height="11" src="https://ssl.pstatic.net/static/movie/2013/07/logo_naver.png" width="63"/></a><!-- N=a:fot.nhn -->
# <em>Copyright ©</em>
# <a href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a><!-- N=a:fot.corp -->
# <span>All Rights Reserved.</span>
# </address>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#
# if (false) {
# 	var alertType = "NONE";
# 	var koreanTitle = "";
# 	var movieCode = "0";
# 	var userReserveCount = "0";
# 	var todayDatetime = "20230213200516";
# 	var endDatetimeAfterTwoDays = "00000000000000";
#
#
# 	if (movieCode > 0) {
# 		openWriteActualPointAlert (alertType, koreanTitle, movieCode, userReserveCount, todayDatetime, endDatetimeAfterTwoDays);
# 	}
# }
#
# function openWriteActualPointAlert (alertType, koreanTitle, movieCode, count, today, endDate) {
# 	if (alertType == "ONE" || alertType == "MORE") {
# 		setCookieLastUserReserveDate(today, endDate);
# 		if (confirm("관람하신 " + koreanTitle + "에\n평점 등록 시 네이버페이 포인트 500원 적립!\n지금 평점쓰기 메뉴로 이동하시겠습니까?")) {
# 			top.location.href = "https://movie.naver.com/movie/bi/mi/point.naver?code=" + movieCode;
# 		}
# 	}
#
# }
#
# function setCookieLastUserReserveDate(today, endDate) {
# 	var cookieForNotOpenActualPointPopup = jindo.$Cookie();
#
#
# 	cookieForNotOpenActualPointPopup.remove("lastUserReserveDatetime");
# 	cookieForNotOpenActualPointPopup.remove("lastUserReserveCheckDatetime");
#
# 	cookieForNotOpenActualPointPopup.set("lastUserReserveDatetime", endDate, 9999, "movie.naver.com");
# 	cookieForNotOpenActualPointPopup.set("lastUserReserveCheckDatetime", today, 9999, "movie.naver.com");
# }
#
# </script>
# <script type="text/javascript">
#
#
#
#
#
# 			var alertMessage = "지원되지 않는 브라우저로 서비스 이용에 제한이 있습니다.";
#
#
#
# 	function getBrowser() {
# 		var ua = navigator.userAgent;
# 		if (/NAVER/.test(ua)) {
# 			return "NAVER_APP";
# 		} else if (/IEMobile/.test(ua)) {
# 			return "INTERNET_EXPLORER_MOBILE";
# 		} else if (/MSIE/.test(ua) || /Trident/.test(ua)) {
# 			return "INTERNET_EXPLORER";
# 		} else if (/Firefox/.test(ua)) {
# 			return "FIREFOX";
# 		} else if (/Opera\//.test(ua) || /OPR\//.test(ua)) {
# 			return "OPERA";
# 		}  else if (/Swing\//.test(ua)) {
# 			return "SWING";
# 		} else if (/Chrome\//.test(ua) || /CriOS\//.test(ua)) {
# 			return "CHROME";
# 		} else if (/BAND\//.test(ua)) {
# 			return "BAND_APP";
# 		} else if (/FBAN\/FBIOS/.test(ua)) {
# 			return "FACEBOOK_APP";
# 		} else if (/Twitter/.test(ua)) {
# 			return "TWITTER_APP";
# 		} else if (/KAKAOTALK/.test(ua)) {
# 			return "KAKAOTALK_APP";
# 		} else if (/Android/.test(ua) && /Safari/.test(ua)) {
# 			return "ANDROID_INTERNET_APP";
# 		} else if (/Safari/.test(ua)) {
# 			return "SAFARI";
# 		}
#
# 		return "";
# 	}
#
# 	if (getBrowser() === "UNKNOWN" && jindo.$Cookie().get("notSupportBrowserAlert") != 'true') {
# 		alert(alertMessage);
# 		jindo.$Cookie().set("notSupportBrowserAlert", "true", "9999", "movie.naver.com");
# 	}
#
#
# </script>
# <!-- //footer -->
# </div>
# <script type="text/javascript">
# var isRecentTab = false;
#
# jindo.$Fn(function (we) {
#
#
# 	// 상단 검색영역
# 	var oSearch = new nhn.movie.Search({
# 		area : "jSearchArea",
# 		autosearch : "https://auto-movie.naver.com/ac?q_enc=UTF-8&st=1&r_lt=1&n_ext=1&t_koreng=1&r_format=json&r_enc=UTF-8&r_unicode=0&r_escape=1&q=",
# 		movelink : "/movie/bi/mi/basic.naver?code=",
# 		peoplelink : "/movie/bi/pi/basic.naver?code="
# 	});
#
#     // 좌측 LNB
#     var oLNB = new nhn.movie.LNB();
# 	if( typeof oViewMode != "undefined") {
# 		oViewMode.attach('change', jindo.$Fn(oLNB.update, oLNB).bind());
# 	}
#
#     // 2단일때, 2열에 상단 회색 라인 없애기
# 	if( typeof oViewMode != "undefined") {
# 	    oViewMode.attach('change', function (oEvent) {
# 	        var welSecondSectionGroup = jindo.$Element('content').queryAll('.section_group')[1];
# 	        var wel2column1rowSection;
#
# 	        if (welSecondSectionGroup) {
# 	            wel2column1rowSection = welSecondSectionGroup.query('.obj_section');
#
# 	            if (oEvent.sStyle == 'wide') {
# 	                wel2column1rowSection.addClass('noline');
# 	            } else {
# 	                wel2column1rowSection.removeClass('noline');
# 	            }
# 	        }
#
# 		    //포토 묻어가기
# 		    if( typeof oPhoto != "undefined" ){
# 			    if (oEvent.sStyle == 'wide') {
# 				    oPhoto.setWide("wide");
# 			    } else {
# 				    oPhoto.setWide("basic");
# 			    }
# 		    }
# 		    // 비디오 묻어가기
# 		    if( typeof oMovie != "undefined" ){
# 			    if (oEvent.sStyle == 'wide') {
# 				    oMovie.setWide("wide", 1);
# 			    } else {
# 				    oMovie.setWide("basic", 1);
# 			    }
# 		    }
#
# 	    });
# 	}
#
#     // 상단썸네일영역
#
#
#
#
#
#     var waelScriptOrderList = jindo.$ElementList('._gnb_another_service_layer');
#
#     jindo.$A(waelScriptOrderList.$value()).forEach(function(value, index, array) {
# 		jindo.$Fn(reviewOrderLayerToggle, this).attach(value, "blur");
# 	});
#     //자동닫힘 기능 끝.
#
#   //영화검색 결과에서 포커스 아웃될 경우, 검색 결과를 지우도록 변경.
#     jindo.$Element("lnb_gonaver").attach("focus",function(e){
#
#     	jindo.$Element('search_placeholder').attr({
#     		"style" : "display: inline;"
#     	})
#     	jindo.$Element('ipt_tx_srch').$value().value="";
#
#     	if(jindo.$Element("jAutoComplate") != null){
#     		jindo.$Element("jAutoComplate").hide();
#     	}
#     });
#
#
#
#
# }).attach(document, 'domready');
# /**
#  * 기타 공통
#  */
# jindo.$Fn(function() {
#     try{ lcs_do(); } catch(e){}
# }).attach(window, "pageshow");
# </script>
# <script type="text/javascript">
# 	//nClick 초기화 영역
# 	//클릭로그 집계 코드 추가
# 	var ccsrv="cc.naver.com";
# 	var nclk_evt = 1;
#
# 	nclk_do();
# 	//nClick 초기화 영역 끝
# </script>
# </body>
# </html>

# %%
r = soup.find_all('dt', {'class': 'tit'})  # //dt[@class="tit"]
print(type(r), len(r))
# for e in r :
#     print(e)
print(r[0], r[-1])
# Out:
# <class 'bs4.element.ResultSet'> 103
# <dt class="tit">
# <span class="ico_rating_12">12세 관람가</span>
# <a href="/movie/bi/mi/basic.naver?code=209331">라스트 버스</a>
# <!-- N=a:nol.title,r:1,i:209331 -->
# </dt> <dt class="tit">
# <a href="/movie/bi/mi/basic.naver?code=13196">애정</a>
# <!-- N=a:nol.title,r:103,i:13196 -->
# </dt>
