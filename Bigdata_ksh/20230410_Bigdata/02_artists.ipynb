# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import matplotlib

matplotlib.rcParams

matplotlib.rcParams['font.family']

current_font_list = matplotlib.rcParams['font.family']

font_path = 'C:\\Windows\\Fonts\\batang.ttc'

kfont = matplotlib.font_manager.FontProperties(fname=font_path).get_name()

matplotlib.rcParams['font.family'] = [kfont] + current_font_list

current_font_list
# Out:
# ['Batang', 'Batang', 'sans-serif']

# %%
pd_data = pd.read_csv('전국신호등표준데이터.csv', encoding='cp949')

pd_data.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21048\3909734075.py:1: DtypeWarning: Columns (3,6,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd_data = pd.read_csv('전국신호등표준데이터.csv', encoding='cp949')
#      시도명 시군구명  도로종류 도로노선번호     도로노선명  도로노선방향 소재지도로명주소              소재지지번주소  \
# 0  대전광역시   서구  특별시도    NaN  계룡로553번길       2      NaN    대전광역시 서구 탄방동 1449
# 1  대전광역시   서구  특별시도    NaN   문정로48번길       2      NaN    대전광역시 서구 탄방동 1453
# 2  대전광역시   서구  특별시도    NaN   문정로40번길       2      NaN     대전광역시 서구 탄방동 658
# 3  대전광역시   서구  특별시도    NaN       문정로       1      NaN  대전광역시 서구 탄방동 1447-1
# 4  대전광역시   서구  특별시도    NaN       문정로       1      NaN  대전광역시 서구 탄방동 1447-1
#
#           위도          경도  ...  점멸등운영종료시각  보행자작동신호기유무 잔여시간표시기유무 시각장애인용음향신호기유무  \
# 0  36.345077  127.385044  ...      00:00           N         Y             N
# 1  36.346298  127.384669  ...      00:00           N         Y             N
# ...

# %%
x = pd_data['위도']
y = pd_data['경도']

fig, axe = plt.subplots()
axe.scatter(y,x, s=15, c='lawngreen', marker='^')    # s = size, c = color, marker = 마커 모양
# axe.set_xticklabels(y, rotation=45)
axe.set_xticklabels(list('abcdefghijk'))
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21048\2682676200.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axe.set_xticklabels(list('abcdefghijk'))
# [Text(125.0, 0, 'a'),
#  Text(125.5, 0, 'b'),
#  Text(126.0, 0, 'c'),
#  Text(126.5, 0, 'd'),
#  Text(127.0, 0, 'e'),
#  Text(127.5, 0, 'f'),
#  Text(128.0, 0, 'g'),
#  Text(128.5, 0, 'h'),
#  Text(129.0, 0, 'i'),
#  Text(129.5, 0, 'j'),
#  Text(130.0, 0, 'k')]

# %%
# pd_data.head()
s2 = pd_data['시도명'].value_counts()

fig,axe = plt.subplots()
# axe.plot(s2.index, s2, color='red', marker='x')
# axe.set_xticklabels(s2.index, rotation=45)
axe.plot(s2.index, s2, 'g^--', label='myline1') # [color][marker][line]
axe.legend(loc='upper left')

# %%
fig, axe = plt.subplots()

s1 = pd_data['시도명'].value_counts()

axe.barh(s1.index, s1, color=['b','g'], label=s1.index)   # bar : 수직, barh : 수평
# axe.legend(s1.index[:2],ncols=2)   # ncols : 컬럼 수 정의
axe.legend(['경기도','대전광역시'])
